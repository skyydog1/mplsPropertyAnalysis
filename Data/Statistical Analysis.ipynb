# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('Assessors_Parcel_Data_2022.csv', low_memory=False)

# %%
pd.set_option('display.max_columns', None)

# %%
data.head(5)
# Out:
#               PIN  ASMTYEAR  TAXYEAR HOUSE_NO STREET_NAME UNIT_NO  ZIP_POSTAL  \
# 0  p0102824130046      2022     2023     3313  25TH AVE S     NaN  55406-2405
# 1  p0102824130047      2022     2023     3317  25TH AVE S     NaN  55406-2405
# 2  p0102824130048      2022     2023     3321  25TH AVE S     NaN  55406-2405
# 3  p0102824130049      2022     2023     3323  25TH AVE S     NaN  55406-2405
# 4  p0102824130050      2022     2023     3327  25TH AVE S     NaN  55406-2405
#
#   FORMATTED_ADDRESS                       OWNERNM                 TAXPAYER1  \
# 0   3313 25TH AVE S      ROBERT JOHN REICHGELD II  ROBERT JOHN REICHGELD II
# 1   3317 25TH AVE S            JLMPW HOLDINGS LLC        JLMPW HOLDINGS LLC
# 2   3321 25TH AVE S  CITY/LAKES COMMUNITY LAND TR         JACKSON J ARCOREN
# 3   3323 25TH AVE S               TIMOTHY GODSILL           TIMOTHY GODSILL
# 4   3327 25TH AVE S           BRANDON V CULBERSON       BRANDON V CULBERSON
#
#            TAXPAYER2               TAXPAYER3               TAXPAYER4  PLAT_NO  \
# 0    3313 25TH AVE S  MINNEAPOLIS MN   55406                     NaN  20330.0
# 1     MATTHEW WAGNER         3317 25TH AVE S  MINNEAPOLIS MN   55406  20330.0
# 2   TERESA E ARCOREN         3321 25TH AVE S  MINNEAPOLIS MN   55406  20330.0
# 3  6011 XERXES AVE S  MINNEAPOLIS MN   55410                     NaN  20330.0
# 4    3327 25TH AVE S  MINNEAPOLIS MN   55406                     NaN  20330.0
#
#   NEIGHBORHOOD   COMMUNITY  WARD ZONING  \
# 0     CORCORAN  POWDERHORN     9    R1A
# 1     CORCORAN  POWDERHORN     9    R1A
# 2     CORCORAN  POWDERHORN     9    R1A
# 3     CORCORAN  POWDERHORN     9    R1A
# 4     CORCORAN  POWDERHORN     9    R1A
#
#                                     LANDUSE  PARCEL_AREA_SQFT              X  \
# 0               2 UNIT RESIDENTIAL - DUPLEX            4811.0  538269.127156
# 1               2 UNIT RESIDENTIAL - DUPLEX            4424.0  538269.460887
# 2  1 UNIT RESIDENTIAL - SINGLE FAMILY HOUSE            4424.0  538269.620689
# 3               2 UNIT RESIDENTIAL - DUPLEX            4424.0  538269.353581
# 4  1 UNIT RESIDENTIAL - SINGLE FAMILY HOUSE            5530.0  538269.477518
#
#                Y   PRIMARY_PROP_TYPE  LANDVALUE  BLDGVALUE  TOTALVALUE  \
# 0  155189.821038  2 UNIT RESIDENTIAL      65000     227000      292000
# 1  155148.792185  2 UNIT RESIDENTIAL      73000     269000      342000
# 2  155110.860945         RESIDENTIAL      24000     204000      228000
# 3  155071.000502  2 UNIT RESIDENTIAL      73000     256000      329000
# 4  155025.357914         RESIDENTIAL      83000     236000      319000
#
#   IS_MULTIPLE_USES   IS_EXEMPT     IS_HOMESTEAD SUB1_PT SUB2_PT SUB3_PT  \
# 0               NO  NOT EXEMPT  NON-HOMESTEADED      DB     NaN     NaN
# 1               NO  NOT EXEMPT  NON-HOMESTEADED      DB     NaN     NaN
# 2               NO  NOT EXEMPT  NON-HOMESTEADED       R     NaN     NaN
# 3               NO  NOT EXEMPT  NON-HOMESTEADED      DB     NaN     NaN
# 4               NO  NOT EXEMPT      HOMESTEADED       R     NaN     NaN
#
#   SUB4_PT SUB1_EXEMPTCD SUB2_EXEMPTCD SUB3_EXEMPTCD SUB4_EXEMPTCD  NUM_BLDGS  \
# 0     NaN           NaN           NaN           NaN           NaN          1
# 1     NaN           NaN           NaN           NaN           NaN          1
# 2     NaN           NaN           NaN           NaN           NaN          1
# 3     NaN           NaN           NaN           NaN           NaN          1
# 4     NaN           NaN           NaN           NaN           NaN          1
#
#            BUILDINGUSE  YEARBUILT  BELOWGROUNDAREA  ABOVEGROUNDAREA  \
# 0               DUPLEX     1900.0              672             1648
# 1               DUPLEX     1962.0             1678             1678
# 2  SINGLE FAMILY HOUSE     2021.0                0             1323
# 3               DUPLEX     1962.0             1683             1692
# 4  SINGLE FAMILY HOUSE     1925.0             1188             1563
#
#    NUM_STORIES  NUM_GAR_STALLS PRIMARYHEATING CONSTRUCTIONTYPE EXTERIORTYPE  \
# 0          2.0               2     FORCED AIR       WOOD FRAME       STUCCO
# 1          1.0               2     FORCED AIR       WOOD FRAME       STUCCO
# 2          1.5               2            NaN       WOOD FRAME         WOOD
# 3          1.0               0     FORCED AIR       WOOD FRAME       STUCCO
# 4          1.2               2     FORCED AIR       WOOD FRAME       STUCCO
#
#     ROOF  TOTAL_UNITS  FIREPLACES  BATHROOMS  BEDROOMS  FID
# 0  GABLE          2.0           0          2         2    1
# 1    HIP          2.0           0          3         6    2
# 2  GABLE          1.0           0          1         2    3
# 3    HIP          2.0           0          3         5    4
# 4  GABLE          1.0           0          2         4    5

# %%
df = data[['X','Y','WARD','LANDVALUE','BLDGVALUE','TOTALVALUE','LANDUSE','PARCEL_AREA_SQFT','BUILDINGUSE','YEARBUILT']]

# %%
df.head(5)
# Out:
#                X              Y  WARD  LANDVALUE  BLDGVALUE  TOTALVALUE  \
# 0  538269.127156  155189.821038     9      65000     227000      292000
# 1  538269.460887  155148.792185     9      73000     269000      342000
# 2  538269.620689  155110.860945     9      24000     204000      228000
# 3  538269.353581  155071.000502     9      73000     256000      329000
# 4  538269.477518  155025.357914     9      83000     236000      319000
#
#                                     LANDUSE  PARCEL_AREA_SQFT  \
# 0               2 UNIT RESIDENTIAL - DUPLEX            4811.0
# 1               2 UNIT RESIDENTIAL - DUPLEX            4424.0
# 2  1 UNIT RESIDENTIAL - SINGLE FAMILY HOUSE            4424.0
# 3               2 UNIT RESIDENTIAL - DUPLEX            4424.0
# 4  1 UNIT RESIDENTIAL - SINGLE FAMILY HOUSE            5530.0
#
#            BUILDINGUSE  YEARBUILT
# 0               DUPLEX     1900.0
# 1               DUPLEX     1962.0
# 2  SINGLE FAMILY HOUSE     2021.0
# 3               DUPLEX     1962.0
# 4  SINGLE FAMILY HOUSE     1925.0

# %%
df = df[((df.TOTALVALUE) != 0) & ((df.BLDGVALUE) != 0) & ((df.LANDVALUE) != 0)] #get rid of 0s

# %%
df['TOTALVALUE'].describe().round()
# Out:
# count       121355.0
# mean        524505.0
# std        2933144.0
# min            200.0
# 25%         218000.0
# 50%         309000.0
# 75%         431000.0
# max      270040000.0
# Name: TOTALVALUE, dtype: float64

# %%
df['TOTALVALUE'].median()
# Out:
# 309000.0

# %%
data[data['TOTALVALUE'] == 270040000.0]
# Out:
#                    PIN  ASMTYEAR  TAXYEAR HOUSE_NO STREET_NAME UNIT_NO  \
# 108935  p2702924110135      2022     2023       80    8TH ST S     NaN
#
#         ZIP_POSTAL FORMATTED_ADDRESS                  OWNERNM  \
# 108935  55402-2113       80 8TH ST S  BRI 1855 IDS CENTER LLC
#
#                        TAXPAYER1              TAXPAYER2  TAXPAYER3  \
# 108935  BRI 1855 IDS CENTER, LLC  100 N FEDERAL HIGHWAY  SUITE 400
#
#                          TAXPAYER4  PLAT_NO   NEIGHBORHOOD COMMUNITY  WARD  \
# 108935  HALLANDALE BEACH, FL 33009   2977.0  DOWNTOWN WEST  DOWNTOWN     7
#
#        ZONING           LANDUSE  PARCEL_AREA_SQFT              X  \
# 108935   B4-2  OFFICE STRUCTURE           91759.0  528792.404435
#
#                     Y PRIMARY_PROP_TYPE  LANDVALUE  BLDGVALUE  TOTALVALUE  \
# 108935  167448.591644        COMMERCIAL   26301300  243738700   270040000
#
#        IS_MULTIPLE_USES   IS_EXEMPT     IS_HOMESTEAD SUB1_PT SUB2_PT SUB3_PT  \
# 108935              YES  NOT EXEMPT  NON-HOMESTEADED       C      LC     NaN
#
#        SUB4_PT SUB1_EXEMPTCD SUB2_EXEMPTCD SUB3_EXEMPTCD SUB4_EXEMPTCD  \
# 108935     NaN           NaN           NaN           NaN           NaN
#
#         NUM_BLDGS BUILDINGUSE  YEARBUILT  BELOWGROUNDAREA  ABOVEGROUNDAREA  \
# 108935          1      OFFICE     1972.0           449162          1645215
#
#         NUM_STORIES  NUM_GAR_STALLS PRIMARYHEATING CONSTRUCTIONTYPE  \
# 108935         57.0             650  DISTRICT HEAT      STEEL FRAME
#
#        EXTERIORTYPE  ROOF  TOTAL_UNITS  FIREPLACES  BATHROOMS  BEDROOMS  \
# 108935        OTHER  FLAT          0.0           0          0         0
#
#            FID
# 108935  108936
